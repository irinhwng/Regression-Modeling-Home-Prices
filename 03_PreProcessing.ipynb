# %% [markdown]
# # In this notebook, I will:
# - Generate polynonmial features without the dummy columns
# - Find the high correlation columns
# - Use those columns and standardize them (this is a new dataframe)
# - Append the standardized dataframe with the three 3 dummy columns shown before

# %%
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
import pandas as pd

# %%
train = pd.read_csv('./datasets/df_with_dummy.csv')
train.head()
# Out:
#    Unnamed: 0  MS SubClass  Lot Frontage  Lot Area  Overall Qual  \
# 0           0           60          68.0     13517             6
# 1           1           60          43.0     11492             7
# 2           2           20          68.0      7922             5
# 3           3           60          73.0      9802             5
# 4           4           50          82.0     14235             6
#
#    Overall Cond  Year Built  Year Remod/Add  Mas Vnr Area  BsmtFin SF 1  \
# 0             8        1976            2005         289.0         533.0
# 1             5        1996            1997         132.0         637.0
# 2             7        1953            2007           0.0         731.0
# 3             5        2006            2007           0.0           0.0
# 4             8        1900            1993           0.0           0.0
#
#         ...         Misc Val  Mo Sold  Yr Sold  SalePrice  homeage  baths  \
# 0       ...                0        3     2010     130500       34    2.5
# 1       ...                0        4     2009     220000       13    2.5
# 2       ...                0        1     2010     109000       57    1.0
# 3       ...                0        4     2010     174000        4    2.5
# 4       ...                0        3     2010     138500      110    2.0
#
#    garageage  Foundation_PConc  Bsmt Qual_Ex  Kitchen Qual_Ex
# 0       34.0                 0             0                0
# 1       12.0                 1             0                0
# 2       57.0                 0             0                0
# 3        3.0                 1             0                0
# 4       53.0                 1             0                0
#
# [5 rows x 44 columns]

# %%
train.shape
# Out:
# (2051, 44)

# %%
#removing dummy column so i can create polynomial features 
numeric_col = []
for col in list(train):
    if '_' not in col: 
        numeric_col.append(col)

# %%
len(numeric_col)
# Out:
# 41

# %%
#removing irrelevant columns 
numeric_col.remove('Unnamed: 0')

# %%
numeric_col.remove('SalePrice')

# %%
len(numeric_col)
# Out:
# 39

# %% [markdown]
# # Polynomial Features

# %%
X = train[numeric_col]

# %%
poly = PolynomialFeatures(include_bias= False)
X_poly = poly.fit_transform(X)

# %%
#creating a dataframe of our polynomial features
poly_df = pd.DataFrame(X_poly, columns = poly.get_feature_names(numeric_col))

# %%
poly_df.shape
# Out:
# (2051, 819)

# %% [markdown]
# # Finding Polynomial Columns with High Correlation

# %%
train['SalePrice'].shape
# Out:
# (2051,)

# %% [markdown]
# #### This time, I am setting the correlation magnitude at 0.70

# %%
corr_col = []
for col in list(poly_df):
    corr = train['SalePrice'].corr(poly_df[col])
    if corr > 0.50 or corr < -.5:
        corr_col.append(col)

# %%
corr_col
# Out:
# ['Overall Qual',
#  'Year Built',
#  'Year Remod/Add',
#  'Mas Vnr Area',
#  'Total Bsmt SF',
#  '1st Flr SF',
#  'Gr Liv Area',
#  'Full Bath',
#  'TotRms AbvGrd',
#  'Garage Yr Blt',
#  'Garage Cars',
#  'Garage Area',
#  'homeage',
#  'baths',
#  'garageage',
#  'Lot Frontage Overall Qual',
#  'Lot Frontage Mas Vnr Area',
#  'Lot Frontage Gr Liv Area',
#  'Lot Frontage Full Bath',
#  'Lot Frontage Garage Cars',
#  'Lot Frontage Garage Area',
#  'Lot Frontage baths',
#  'Lot Area Overall Qual',
#  'Lot Area Garage Cars',
#  'Overall Qual^2',
#  'Overall Qual Overall Cond',
#  'Overall Qual Year Built',
#  'Overall Qual Year Remod/Add',
#  'Overall Qual Mas Vnr Area',
#  'Overall Qual BsmtFin SF 1',
#  'Overall Qual Total Bsmt SF',
#  'Overall Qual 1st Flr SF',
#  'Overall Qual Gr Liv Area',
#  'Overall Qual Full Bath',
#  'Overall Qual Bedroom AbvGr',
#  'Overall Qual Kitchen AbvGr',
#  'Overall Qual TotRms AbvGrd',
#  'Overall Qual Fireplaces',
#  'Overall Qual Garage Yr Blt',
#  'Overall Qual Garage Cars',
#  'Overall Qual Garage Area',
#  'Overall Qual Yr Sold',
#  'Overall Qual baths',
#  'Overall Cond Total Bsmt SF',
#  'Overall Cond 1st Flr SF',
#  'Overall Cond Gr Liv Area',
#  'Overall Cond Garage Cars',
#  'Overall Cond Garage Area',
#  'Overall Cond baths',
#  'Year Built^2',
#  'Year Built Year Remod/Add',
#  'Year Built Mas Vnr Area',
#  'Year Built Total Bsmt SF',
#  'Year Built 1st Flr SF',
#  'Year Built Gr Liv Area',
#  'Year Built Full Bath',
#  'Year Built TotRms AbvGrd',
#  'Year Built Garage Yr Blt',
#  'Year Built Garage Cars',
#  'Year Built Garage Area',
#  'Year Built Yr Sold',
#  'Year Built homeage',
#  'Year Built baths',
#  'Year Built garageage',
#  'Year Remod/Add^2',
#  'Year Remod/Add Mas Vnr Area',
#  'Year Remod/Add Total Bsmt SF',
#  'Year Remod/Add 1st Flr SF',
#  'Year Remod/Add Gr Liv Area',
#  'Year Remod/Add Full Bath',
#  'Year Remod/Add TotRms AbvGrd',
#  'Year Remod/Add Garage Yr Blt',
#  'Year Remod/Add Garage Cars',
#  'Year Remod/Add Garage Area',
#  'Year Remod/Add Yr Sold',
#  'Year Remod/Add homeage',
#  'Year Remod/Add baths',
#  'Year Remod/Add garageage',
#  'Mas Vnr Area Total Bsmt SF',
#  'Mas Vnr Area 1st Flr SF',
#  'Mas Vnr Area Gr Liv Area',
#  'Mas Vnr Area Full Bath',
#  'Mas Vnr Area Bedroom AbvGr',
#  'Mas Vnr Area TotRms AbvGrd',
#  'Mas Vnr Area Fireplaces',
#  'Mas Vnr Area Garage Yr Blt',
#  'Mas Vnr Area Garage Cars',
#  'Mas Vnr Area Garage Area',
#  'Mas Vnr Area Yr Sold',
#  'Mas Vnr Area baths',
#  'BsmtFin SF 1 Full Bath',
#  'BsmtFin SF 1 Garage Cars',
#  'BsmtFin SF 1 baths',
#  'Total Bsmt SF 1st Flr SF',
#  'Total Bsmt SF Gr Liv Area',
#  'Total Bsmt SF Full Bath',
#  'Total Bsmt SF Bedroom AbvGr',
#  'Total Bsmt SF TotRms AbvGrd',
#  'Total Bsmt SF Fireplaces',
#  'Total Bsmt SF Garage Yr Blt',
#  'Total Bsmt SF Garage Cars',
#  'Total Bsmt SF Garage Area',
#  'Total Bsmt SF Yr Sold',
#  'Total Bsmt SF baths',
#  '1st Flr SF^2',
#  '1st Flr SF Gr Liv Area',
#  '1st Flr SF Full Bath',
#  '1st Flr SF TotRms AbvGrd',
#  '1st Flr SF Fireplaces',
#  '1st Flr SF Garage Yr Blt',
#  '1st Flr SF Garage Cars',
#  '1st Flr SF Garage Area',
#  '1st Flr SF Yr Sold',
#  '1st Flr SF baths',
#  'Gr Liv Area^2',
#  'Gr Liv Area Full Bath',
#  'Gr Liv Area TotRms AbvGrd',
#  'Gr Liv Area Fireplaces',
#  'Gr Liv Area Garage Yr Blt',
#  'Gr Liv Area Garage Cars',
#  'Gr Liv Area Garage Area',
#  'Gr Liv Area Yr Sold',
#  'Gr Liv Area baths',
#  'Full Bath^2',
#  'Full Bath TotRms AbvGrd',
#  'Full Bath Fireplaces',
#  'Full Bath Garage Yr Blt',
#  'Full Bath Garage Cars',
#  'Full Bath Garage Area',
#  'Full Bath Yr Sold',
#  'Full Bath baths',
#  'Bedroom AbvGr Garage Cars',
#  'Bedroom AbvGr Garage Area',
#  'Kitchen AbvGr Garage Cars',
#  'Kitchen AbvGr Garage Area',
#  'Kitchen AbvGr homeage',
#  'Kitchen AbvGr garageage',
#  'TotRms AbvGrd Fireplaces',
#  'TotRms AbvGrd Garage Yr Blt',
#  'TotRms AbvGrd Garage Cars',
#  'TotRms AbvGrd Garage Area',
#  'TotRms AbvGrd Yr Sold',
#  'TotRms AbvGrd baths',
#  'Fireplaces Garage Cars',
#  'Fireplaces Garage Area',
#  'Fireplaces baths',
#  'Garage Yr Blt^2',
#  'Garage Yr Blt Garage Cars',
#  'Garage Yr Blt Garage Area',
#  'Garage Yr Blt Yr Sold',
#  'Garage Yr Blt homeage',
#  'Garage Yr Blt baths',
#  'Garage Yr Blt garageage',
#  'Garage Cars^2',
#  'Garage Cars Garage Area',
#  'Garage Cars Yr Sold',
#  'Garage Cars baths',
#  'Garage Area^2',
#  'Garage Area Yr Sold',
#  'Garage Area baths',
#  'Yr Sold homeage',
#  'Yr Sold baths',
#  'Yr Sold garageage',
#  'baths^2']

# %%
len(corr_col)
# Out:
# 164

# %%
poly_df[corr_col].head()
# Out:
#    Overall Qual  Year Built  Year Remod/Add  Mas Vnr Area  Total Bsmt SF  \
# 0           6.0      1976.0          2005.0         289.0          725.0
# 1           7.0      1996.0          1997.0         132.0          913.0
# 2           5.0      1953.0          2007.0           0.0         1057.0
# 3           5.0      2006.0          2007.0           0.0          384.0
# 4           6.0      1900.0          1993.0           0.0          676.0
#
#    1st Flr SF  Gr Liv Area  Full Bath  TotRms AbvGrd  Garage Yr Blt   ...     \
# 0       725.0       1479.0        2.0            6.0         1976.0   ...
# 1       913.0       2122.0        2.0            8.0         1997.0   ...
# 2      1057.0       1057.0        1.0            5.0         1953.0   ...
# 3       744.0       1444.0        2.0            7.0         2007.0   ...
# 4       831.0       1445.0        2.0            6.0         1957.0   ...
#
#    Garage Cars Garage Area  Garage Cars Yr Sold  Garage Cars baths  \
# 0                    950.0               4020.0                5.0
# 1                   1118.0               4018.0                5.0
# 2                    246.0               2010.0                1.0
# 3                    800.0               4020.0                5.0
# 4                    968.0               4020.0                4.0
#
#    Garage Area^2  Garage Area Yr Sold  Garage Area baths  Yr Sold homeage  \
# 0       225625.0             954750.0             1187.5          68340.0
# 1       312481.0            1123031.0             1397.5          26117.0
# 2        60516.0             494460.0              246.0         114570.0
# 3       160000.0             804000.0             1000.0           8040.0
# 4       234256.0             972840.0              968.0         221100.0
#
#    Yr Sold baths  Yr Sold garageage  baths^2
# 0         5025.0            68340.0     6.25
# 1         5022.5            24108.0     6.25
# 2         2010.0           114570.0     1.00
# 3         5025.0             6030.0     6.25
# 4         4020.0           106530.0     4.00
#
# [5 rows x 164 columns]

# %% [markdown]
# # At this point, `poly_df[corr_col]` has only columns with polynomial features. Now let's standardize it!

# %%
#I want to standardize my new polynomial features 
X = poly_df[corr_col]

# %%
ss= StandardScaler()
ss.fit(X)  #learning the means and std for each column 
poly_scaled = ss.transform(X)

# %%
poly = pd.DataFrame(poly_scaled, columns = corr_col)

# %%
poly.head()
# Out:
#    Overall Qual  Year Built  Year Remod/Add  Mas Vnr Area  Total Bsmt SF  \
# 0     -0.078644    0.142227        0.989479      1.092329      -0.741232
# 1      0.622656    0.805126        0.609090      0.191491      -0.322705
# 2     -0.779944   -0.620106        1.084576     -0.565901      -0.002130
# 3     -0.779944    1.136575        1.084576     -0.565901      -1.500370
# 4     -0.078644   -2.376787        0.418896     -0.565901      -0.850317
#
#    1st Flr SF  Gr Liv Area  Full Bath  TotRms AbvGrd  Garage Yr Blt    ...     \
# 0   -1.108838    -0.040634   0.769779      -0.279441      -0.112447    ...
# 1   -0.634510     1.244529   0.769779       1.002738       0.737090    ...
# 2   -0.271195    -0.884084  -1.051232      -0.920531      -1.042893    ...
# 3   -1.060900    -0.110588   0.769779       0.361648       1.141632    ...
# 4   -0.841397    -0.108589   0.769779      -0.279441      -0.881076    ...
#
#    Garage Cars Garage Area  Garage Cars Yr Sold  Garage Cars baths  \
# 0                -0.052622             0.295128           0.737673
# 1                 0.174714             0.293824           0.737673
# 2                -1.005270            -1.014939          -1.075350
# 3                -0.255601             0.295128           0.737673
# 4                -0.028265             0.295128           0.284417
#
#    Garage Area^2  Garage Area Yr Sold  Garage Area baths  Yr Sold homeage  \
# 0      -0.199323             0.008581           0.496281        -0.067210
# 1       0.182637             0.396922           0.848706        -0.763445
# 2      -0.925409            -1.053629          -1.083758         0.695100
# 3      -0.487916            -0.339305           0.181616        -1.061526
# 4      -0.161367             0.050327           0.127913         2.451726
#
#    Yr Sold baths  Yr Sold garageage   baths^2
# 0       1.160521           0.203566  1.138397
# 1       1.158568          -0.686130  1.138397
# 2      -1.194594           1.133449 -1.046041
# 3       1.160521          -1.049756  1.138397
# 4       0.375483           0.971731  0.202209
#
# [5 rows x 164 columns]

# %%
append_col = ['Foundation_PConc','Bsmt Qual_Ex', 'Kitchen Qual_Ex', 'SalePrice']
#adding the three dummy columns and saleprice

# %%
train[append_col].head()
# Out:
#    Foundation_PConc  Bsmt Qual_Ex  Kitchen Qual_Ex  SalePrice
# 0                 0             0                0     130500
# 1                 1             0                0     220000
# 2                 0             0                0     109000
# 3                 1             0                0     174000
# 4                 1             0                0     138500

# %%
mother = pd.concat(objs=[poly, train[append_col]], axis='columns')

# %%
mother.shape
# Out:
# (2051, 168)

# %% [markdown]
# # We finally made the mother dataframe! These are the features I picked. The workflow process fro preprocessing are as follows:
# - Genrate polynomial features without dummy
# - Find high correlation of those polynomial features
# - Standardize those specific features
# - Append three dummies and `SalePrice`
#
# **This medium blog helped me streamline my preprocessing workflow.**
# - https://medium.com/@samchaaa/preprocessing-why-you-should-generate-polynomial-features-first-before-standardizing-892b4326a91d

# %%
mother.to_csv('./datasets/mother.csv')

# %% [markdown]
# # This mother data contains:
# - Non-standardized `SalePrice` column
# - Three non-standardized dummy columns
# - Nine polynomial and standardized columns
#
# Besides the `SalePrice` column, these are my 9 features.
